# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data0 = pd.read_csv('20皮尔逊02.csv', index_col = None)
data0.head(2)
# Out:
#    formation energy  avg_dev Electronegativity  range Electronegativity  \
# 0            -3.105                   0.873469                     2.55
# 1            -2.819                   0.822222                     2.46
#
#    maximum Electronegativity  mode Electronegativity  mean SpaceGroupNumber  \
# 0                       3.44                    3.44              87.000000
# 1                       3.44                    3.44              87.444444
#
#    mode SpaceGroupNumber  mean Electronegativity  mean NdValence  \
# 0                     12                2.675714             0.0
# 1                     12                2.700000             0.0
#
#    range CovalentRadius  range SpaceGroupNumber
# 0                   149                     217
# 1                    62                     217

# %%
data_corresponding = data0.corr()['formation energy'].abs().sort_values(ascending=False)[:11]
data_corresponding
# Out:
# formation energy             1.000000
# avg_dev Electronegativity    0.815780
# range Electronegativity      0.783646
# maximum Electronegativity    0.743645
# mode Electronegativity       0.712911
# mean SpaceGroupNumber        0.618328
# mode SpaceGroupNumber        0.618207
# mean Electronegativity       0.616593
# mean NdValence               0.607419
# range CovalentRadius         0.589170
# range SpaceGroupNumber       0.584160
# Name: formation energy, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
sorted_data = data_corresponding.drop('formation energy').sort_values(ascending=True)  # 注意这里的排序方式
sorted_data.plot(kind='barh', alpha=0.7, color = 'dodgerblue', edgecolor = 'k',figsize=(8, 6))
plt.xticks(fontproperties='Times New Roman', fontsize=18, weight='bold')
plt.yticks(fontproperties='Times New Roman', fontsize=18, weight='bold')
plt.savefig('a03.png', dpi=600, format='png', bbox_inches='tight')
plt.show()

# %%
sorted_data = data_corresponding.drop('formation energy').sort_values(ascending=True)  # 注意这里的排序方式
sorted_data.plot(kind='barh', alpha=0.7, color = 'dodgerblue', edgecolor = 'k',figsize=(8, 6))
plt.xticks(fontproperties='Times New Roman', fontsize=18, weight='bold')
plt.yticks(fontproperties='Times New Roman', fontsize=18, weight='bold')
plt.savefig('a04.png', dpi=600, format='png', bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(12,12))
sns.heatmap(data0.corr(), cmap='RdYlGn', square=True)
plt.xticks(fontproperties='Times New Roman', fontsize=18, weight='bold')
plt.yticks(fontproperties='Times New Roman', fontsize=18, weight='bold')
plt.title('Characteristic heat map',fontproperties='Times New Roman',fontsize=18, weight='bold')
plt.savefig('皮尔逊热图.png', dpi=600, format='png', bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(12,12))
sns.heatmap(data0.corr(), cmap='GnBu', square=True)
plt.xticks(fontproperties='Times New Roman', fontsize=18, weight='bold')
plt.yticks(fontproperties='Times New Roman', fontsize=18, weight='bold')
plt.title('Characteristic heat map',fontproperties='Times New Roman',fontsize=18, weight='bold')
plt.savefig('皮尔逊热图01.png', dpi=600, format='png', bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10,10))
sns.heatmap(data0.corr(), cmap='Blues', square=True)
plt.xticks(fontproperties='Times New Roman', fontsize=18, weight='bold')
plt.yticks(fontproperties='Times New Roman', fontsize=18, weight='bold')
plt.savefig('a06.png', dpi=600, format='png', bbox_inches='tight')
plt.show()
